# %%
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import os
import json
import datetime as dt
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16, 10]
plt.rcParams['font.size'] = 14
import seaborn as sns
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation
from tensorflow.keras.metrics import categorical_accuracy, top_k_categorical_accuracy, categorical_crossentropy
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.applications.mobilenet import preprocess_input
start = dt.datetime.now()

# %%
from tensorflow.keras import backend as K
def focal_loss(gamma=2., alpha=.25):
    def focal_loss_fixed(y_true, y_pred):
        pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
        pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))
        return -K.sum(alpha * K.pow(1. - pt_1, gamma) * K.log(pt_1))-K.sum((1-alpha) * K.pow( pt_0, gamma) * K.log(1. - pt_0))
    return focal_loss_fixed

# %%
DP_DIR = 'E:\\DLDATA\\all'
INPUT_DIR = 'E:\\DLDATA\\all\\'

BASE_SIZE = 256
NCSVS = 100
NCATS = 340
np.random.seed(seed=1987)
tf.set_random_seed(seed=1987)

def f2cat(filename: str) -> str:
    return filename.split('.')[0]

def list_all_categories():
    files = os.listdir(os.path.join(INPUT_DIR, 'train_simplified'))
    return sorted([f2cat(f) for f in files], key=str.lower)

# %%
def apk(actual, predicted, k=3):
    """
    Source: https://github.com/benhamner/Metrics/blob/master/Python/ml_metrics/average_precision.py
    """
    if len(predicted) > k:
        predicted = predicted[:k]
    score = 0.0
    num_hits = 0.0
    for i, p in enumerate(predicted):
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i + 1.0)
    if not actual:
        return 0.0
    return score / min(len(actual), k)
def mapk(actual, predicted, k=3):
    """
    Source: https://github.com/benhamner/Metrics/blob/master/Python/ml_metrics/average_precision.py
    """
    return np.mean([apk(a, p, k) for a, p in zip(actual, predicted)])

def preds2catids(predictions):
    return pd.DataFrame(np.argsort(-predictions, axis=1)[:, :3], columns=['a', 'b', 'c'])

def top_3_accuracy(y_true, y_pred):
    return top_k_categorical_accuracy(y_true, y_pred, k=3)

# %%
STEPS = 800
EPOCHS = 16
size = 64
batchsize = 680

# %%
model = MobileNet(input_shape=(size, size, 1), alpha=1., weights=None, classes=NCATS)
model.compile(optimizer=Adam(lr=0.002), loss=[focal_loss(gamma=2., alpha=.25)],
              metrics=[categorical_crossentropy, categorical_accuracy, top_3_accuracy])
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 1)         0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 65, 65, 1)         0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 32, 32, 32)        288
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 32, 32, 32)        128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 32, 32, 32)        0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 32, 32, 32)        288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 32, 32, 32)        128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 32, 32, 32)        0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 32, 32, 64)        2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 32, 32, 64)        256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 32, 32, 64)        0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 33, 33, 64)        0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 16, 16, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 16, 16, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 16, 16, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 16, 16, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 16, 16, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 16, 16, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 16, 16, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 16, 16, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 16, 16, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 16, 16, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 16, 16, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 16, 16, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 17, 17, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 8, 8, 128)         1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 8, 8, 128)         512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 8, 8, 128)         0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 8, 8, 256)         32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 8, 8, 256)         2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 8, 8, 256)         65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 9, 9, 256)         0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 4, 4, 256)         2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 4, 4, 256)         1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 4, 4, 256)         0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 4, 4, 512)         131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 5, 5, 512)         0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 2, 2, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 2, 2, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 2, 2, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 2, 2, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 2, 2, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 2, 2, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 2, 2, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 2, 2, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 2, 2, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 2, 2, 1024)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 1, 1, 1024)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 1024)        0
# _________________________________________________________________
# conv_preds (Conv2D)          (None, 1, 1, 340)         348500
# _________________________________________________________________
# act_softmax (Activation)     (None, 1, 1, 340)         0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 340)               0
# =================================================================
# Total params: 3,576,788
# Trainable params: 3,554,900
# Non-trainable params: 21,888
# _________________________________________________________________
# None

# %%
def draw_cv2(raw_strokes, size=256, lw=6, time_color=True):
    img = np.zeros((BASE_SIZE, BASE_SIZE), np.uint8)
    for t, stroke in enumerate(raw_strokes):
        for i in range(len(stroke[0]) - 1):
            color = 255 - min(t, 10) * 13 if time_color else 255
            _ = cv2.line(img, (stroke[0][i], stroke[1][i]),
                         (stroke[0][i + 1], stroke[1][i + 1]), color, lw)
    if size != BASE_SIZE:
        return cv2.resize(img, (size, size))
    else:
        return img

def image_generator_xd(size, batchsize, ks, lw=6, time_color=True):
    while True:
        for k in np.random.permutation(ks):
            filename = os.path.join(DP_DIR, 'train_k{}.csv.gz'.format(k))
            for df in pd.read_csv(filename, chunksize=batchsize):
                df['drawing'] = df['drawing'].apply(json.loads)
                x = np.zeros((len(df), size, size, 1))
                for i, raw_strokes in enumerate(df.drawing.values):
                    x[i, :, :, 0] = draw_cv2(raw_strokes, size=size, lw=lw,
                                             time_color=time_color)
                x = preprocess_input(x).astype(np.float32)
                y = keras.utils.to_categorical(df.y, num_classes=NCATS)
                yield x, y

def df_to_image_array_xd(df, size, lw=6, time_color=True):
    df['drawing'] = df['drawing'].apply(json.loads)
    x = np.zeros((len(df), size, size, 1))
    for i, raw_strokes in enumerate(df.drawing.values):
        x[i, :, :, 0] = draw_cv2(raw_strokes, size=size, lw=lw, time_color=time_color)
    x = preprocess_input(x).astype(np.float32)
    return x

# %%
valid_df = pd.read_csv(os.path.join(DP_DIR, 'train_k{}.csv.gz'.format(NCSVS - 1)), nrows=34000)
x_valid = df_to_image_array_xd(valid_df, size)
y_valid = keras.utils.to_categorical(valid_df.y, num_classes=NCATS)
print(x_valid.shape, y_valid.shape)
print('Validation array memory {:.2f} GB'.format(x_valid.nbytes / 1024.**3 ))
# Out:
# (34000, 64, 64, 1) (34000, 340)
# Validation array memory 0.52 GB

# %%
train_datagen = image_generator_xd(size=size, batchsize=batchsize, ks=range(NCSVS - 1))

# %%
x, y = next(train_datagen)
n = 8
fig, axs = plt.subplots(nrows=n, ncols=n, sharex=True, sharey=True, figsize=(12, 12))
for i in range(n**2):
    ax = axs[i // n, i % n]
    (-x[i]+1)/2
    ax.imshow((-x[i, :, :, 0] + 1)/2, cmap=plt.cm.gray)
    ax.axis('off')
plt.tight_layout()
fig.savefig('gs.png', dpi=300)
plt.show();

# %%
x, y = next(train_datagen)

# %%
callbacks = [
    ReduceLROnPlateau(monitor='val_top_3_accuracy', factor=0.75, patience=3, min_delta=0.001,
                          mode='max', min_lr=1e-5, verbose=1),
    ModelCheckpoint('MobileV1FL.h5', monitor='val_top_3_accuracy', mode='max', save_best_only=True,
                    save_weights_only=True),
]
hists = []
hist = model.fit_generator(
    train_datagen, steps_per_epoch=STEPS, epochs=70, verbose=1,
    validation_data=(x_valid, y_valid),
    callbacks = callbacks
)
hists.append(hist)
# Out:
# Epoch 1/70
# 800/800 [==============================] - 345s 431ms/step - loss: 443.6061 - categorical_crossentropy: 2.8638 - categorical_accuracy: 0.3651 - top_3_accuracy: 0.5562 - val_loss: 401.9399 - val_categorical_crossentropy: 2.5486 - val_categorical_accuracy: 0.3901 - val_top_3_accuracy: 0.6136
# Epoch 2/70
# 800/800 [==============================] - 329s 412ms/step - loss: 255.3281 - categorical_crossentropy: 1.7976 - categorical_accuracy: 0.5755 - top_3_accuracy: 0.7805 - val_loss: 344.2497 - val_categorical_crossentropy: 2.2644 - val_categorical_accuracy: 0.4593 - val_top_3_accuracy: 0.6800
# Epoch 3/70
# 800/800 [==============================] - 330s 412ms/step - loss: 222.0995 - categorical_crossentropy: 1.5991 - categorical_accuracy: 0.6238 - top_3_accuracy: 0.8183 - val_loss: 260.7137 - val_categorical_crossentropy: 1.7994 - val_categorical_accuracy: 0.5651 - val_top_3_accuracy: 0.7778
# Epoch 4/70
# 800/800 [==============================] - 330s 412ms/step - loss: 204.1697 - categorical_crossentropy: 1.4924 - categorical_accuracy: 0.6511 - top_3_accuracy: 0.8373 - val_loss: 233.8535 - val_categorical_crossentropy: 1.6613 - val_categorical_accuracy: 0.6009 - val_top_3_accuracy: 0.8096
# Epoch 5/70
# 800/800 [==============================] - 328s 410ms/step - loss: 193.2256 - categorical_crossentropy: 1.4246 - categorical_accuracy: 0.6683 - top_3_accuracy: 0.8490 - val_loss: 213.5854 - val_categorical_crossentropy: 1.5499 - val_categorical_accuracy: 0.6358 - val_top_3_accuracy: 0.8294
# Epoch 6/70
# 800/800 [==============================] - 330s 413ms/step - loss: 185.3479 - categorical_crossentropy: 1.3767 - categorical_accuracy: 0.6798 - top_3_accuracy: 0.8569 - val_loss: 195.6297 - val_categorical_crossentropy: 1.4319 - val_categorical_accuracy: 0.6641 - val_top_3_accuracy: 0.8496
# Epoch 7/70
# 800/800 [==============================] - 330s 413ms/step - loss: 179.8190 - categorical_crossentropy: 1.3412 - categorical_accuracy: 0.6892 - top_3_accuracy: 0.8627 - val_loss: 209.0803 - val_categorical_crossentropy: 1.5046 - val_categorical_accuracy: 0.6402 - val_top_3_accuracy: 0.8324
# Epoch 8/70
# 800/800 [==============================] - 329s 412ms/step - loss: 174.3900 - categorical_crossentropy: 1.3087 - categorical_accuracy: 0.6978 - top_3_accuracy: 0.8683 - val_loss: 218.6981 - val_categorical_crossentropy: 1.5947 - val_categorical_accuracy: 0.6259 - val_top_3_accuracy: 0.8233
# Epoch 9/70
# 800/800 [==============================] - 331s 414ms/step - loss: 169.6685 - categorical_crossentropy: 1.2803 - categorical_accuracy: 0.7045 - top_3_accuracy: 0.8730 - val_loss: 183.0276 - val_categorical_crossentropy: 1.3513 - val_categorical_accuracy: 0.6831 - val_top_3_accuracy: 0.8590
# Epoch 10/70
# 800/800 [==============================] - 330s 413ms/step - loss: 166.8299 - categorical_crossentropy: 1.2608 - categorical_accuracy: 0.7097 - top_3_accuracy: 0.8752 - val_loss: 180.7577 - val_categorical_crossentropy: 1.3563 - val_categorical_accuracy: 0.6859 - val_top_3_accuracy: 0.8604
# Epoch 11/70
# 800/800 [==============================] - 331s 413ms/step - loss: 163.8371 - categorical_crossentropy: 1.2440 - categorical_accuracy: 0.7141 - top_3_accuracy: 0.8785 - val_loss: 648.5356 - val_categorical_crossentropy: 3.9841 - val_categorical_accuracy: 0.1930 - val_top_3_accuracy: 0.3384
# Epoch 12/70
# 800/800 [==============================] - 330s 413ms/step - loss: 159.9433 - categorical_crossentropy: 1.2198 - categorical_accuracy: 0.7201 - top_3_accuracy: 0.8821 - val_loss: 470.0890 - val_categorical_crossentropy: 2.9189 - val_categorical_accuracy: 0.3434 - val_top_3_accuracy: 0.5486
# Epoch 13/70
# 800/800 [==============================] - 331s 413ms/step - loss: 157.8332 - categorical_crossentropy: 1.2049 - categorical_accuracy: 0.7244 - top_3_accuracy: 0.8842 - val_loss: 168.1155 - val_categorical_crossentropy: 1.2596 - val_categorical_accuracy: 0.7072 - val_top_3_accuracy: 0.8746
# Epoch 14/70
# 800/800 [==============================] - 331s 414ms/step - loss: 155.8920 - categorical_crossentropy: 1.1940 - categorical_accuracy: 0.7267 - top_3_accuracy: 0.8860 - val_loss: 260.1713 - val_categorical_crossentropy: 1.8143 - val_categorical_accuracy: 0.5755 - val_top_3_accuracy: 0.7816
# Epoch 15/70
# 800/800 [==============================] - 329s 412ms/step - loss: 153.0550 - categorical_crossentropy: 1.1760 - categorical_accuracy: 0.7314 - top_3_accuracy: 0.8887 - val_loss: 164.0344 - val_categorical_crossentropy: 1.2314 - val_categorical_accuracy: 0.7114 - val_top_3_accuracy: 0.8793
# Epoch 16/70
# 800/800 [==============================] - 331s 414ms/step - loss: 152.3912 - categorical_crossentropy: 1.1708 - categorical_accuracy: 0.7324 - top_3_accuracy: 0.8893 - val_loss: 161.6256 - val_categorical_crossentropy: 1.2277 - val_categorical_accuracy: 0.7171 - val_top_3_accuracy: 0.8793
# Epoch 17/70
# 800/800 [==============================] - 331s 413ms/step - loss: 150.2143 - categorical_crossentropy: 1.1574 - categorical_accuracy: 0.7361 - top_3_accuracy: 0.8913 - val_loss: 159.6837 - val_categorical_crossentropy: 1.2239 - val_categorical_accuracy: 0.7210 - val_top_3_accuracy: 0.8818
# Epoch 18/70
# 800/800 [==============================] - 331s 413ms/step - loss: 148.9255 - categorical_crossentropy: 1.1485 - categorical_accuracy: 0.7375 - top_3_accuracy: 0.8931 - val_loss: 155.8069 - val_categorical_crossentropy: 1.1936 - val_categorical_accuracy: 0.7280 - val_top_3_accuracy: 0.8851
# Epoch 19/70
# 800/800 [==============================] - 330s 412ms/step - loss: 148.1897 - categorical_crossentropy: 1.1446 - categorical_accuracy: 0.7402 - top_3_accuracy: 0.8930 - val_loss: 158.7008 - val_categorical_crossentropy: 1.2151 - val_categorical_accuracy: 0.7235 - val_top_3_accuracy: 0.8849
# Epoch 20/70
# 800/800 [==============================] - 331s 413ms/step - loss: 147.0319 - categorical_crossentropy: 1.1366 - categorical_accuracy: 0.7424 - top_3_accuracy: 0.8943 - val_loss: 152.0013 - val_categorical_crossentropy: 1.1782 - val_categorical_accuracy: 0.7333 - val_top_3_accuracy: 0.8887
# Epoch 21/70
# 800/800 [==============================] - 329s 412ms/step - loss: 145.9287 - categorical_crossentropy: 1.1309 - categorical_accuracy: 0.7436 - top_3_accuracy: 0.8957 - val_loss: 154.6997 - val_categorical_crossentropy: 1.1882 - val_categorical_accuracy: 0.7296 - val_top_3_accuracy: 0.8869
# Epoch 22/70
# 800/800 [==============================] - 331s 413ms/step - loss: 143.7915 - categorical_crossentropy: 1.1175 - categorical_accuracy: 0.7466 - top_3_accuracy: 0.8973 - val_loss: 162.2510 - val_categorical_crossentropy: 1.2373 - val_categorical_accuracy: 0.7179 - val_top_3_accuracy: 0.8795
# Epoch 23/70
# 799/800 [============================>.] - ETA: 0s - loss: 143.0213 - categorical_crossentropy: 1.1117 - categorical_accuracy: 0.7479 - top_3_accuracy: 0.8978
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.001500000071246177.
# 800/800 [==============================] - 330s 412ms/step - loss: 143.0070 - categorical_crossentropy: 1.1116 - categorical_accuracy: 0.7480 - top_3_accuracy: 0.8978 - val_loss: 163.1640 - val_categorical_crossentropy: 1.2584 - val_categorical_accuracy: 0.7162 - val_top_3_accuracy: 0.8781
# Epoch 24/70
# 800/800 [==============================] - 330s 413ms/step - loss: 138.6886 - categorical_crossentropy: 1.0866 - categorical_accuracy: 0.7558 - top_3_accuracy: 0.9020 - val_loss: 144.7014 - val_categorical_crossentropy: 1.1272 - val_categorical_accuracy: 0.7468 - val_top_3_accuracy: 0.8964
# Epoch 25/70
# 800/800 [==============================] - 329s 412ms/step - loss: 138.1484 - categorical_crossentropy: 1.0822 - categorical_accuracy: 0.7567 - top_3_accuracy: 0.9026 - val_loss: 218.1405 - val_categorical_crossentropy: 1.5858 - val_categorical_accuracy: 0.6305 - val_top_3_accuracy: 0.8246
# Epoch 26/70
# 800/800 [==============================] - 330s 412ms/step - loss: 136.4653 - categorical_crossentropy: 1.0739 - categorical_accuracy: 0.7598 - top_3_accuracy: 0.9034 - val_loss: 145.0999 - val_categorical_crossentropy: 1.1256 - val_categorical_accuracy: 0.7461 - val_top_3_accuracy: 0.8949
# Epoch 27/70
# 799/800 [============================>.] - ETA: 0s - loss: 135.3221 - categorical_crossentropy: 1.0655 - categorical_accuracy: 0.7609 - top_3_accuracy: 0.9044
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.001125000009778887.
# 800/800 [==============================] - 328s 410ms/step - loss: 135.3279 - categorical_crossentropy: 1.0655 - categorical_accuracy: 0.7609 - top_3_accuracy: 0.9044 - val_loss: 201.1105 - val_categorical_crossentropy: 1.4963 - val_categorical_accuracy: 0.6546 - val_top_3_accuracy: 0.8441
# Epoch 28/70
# 800/800 [==============================] - 329s 411ms/step - loss: 133.0549 - categorical_crossentropy: 1.0503 - categorical_accuracy: 0.7652 - top_3_accuracy: 0.9066 - val_loss: 136.3656 - val_categorical_crossentropy: 1.0650 - val_categorical_accuracy: 0.7613 - val_top_3_accuracy: 0.9031
# Epoch 29/70
# 800/800 [==============================] - 330s 413ms/step - loss: 131.9854 - categorical_crossentropy: 1.0437 - categorical_accuracy: 0.7672 - top_3_accuracy: 0.9076 - val_loss: 135.1976 - val_categorical_crossentropy: 1.0618 - val_categorical_accuracy: 0.7621 - val_top_3_accuracy: 0.9039
# Epoch 30/70
# 800/800 [==============================] - 330s 412ms/step - loss: 132.2004 - categorical_crossentropy: 1.0452 - categorical_accuracy: 0.7666 - top_3_accuracy: 0.9074 - val_loss: 134.5231 - val_categorical_crossentropy: 1.0613 - val_categorical_accuracy: 0.7636 - val_top_3_accuracy: 0.9054
# Epoch 31/70
# 800/800 [==============================] - 330s 412ms/step - loss: 130.9997 - categorical_crossentropy: 1.0388 - categorical_accuracy: 0.7684 - top_3_accuracy: 0.9083 - val_loss: 133.7896 - val_categorical_crossentropy: 1.0579 - val_categorical_accuracy: 0.7628 - val_top_3_accuracy: 0.9055
# Epoch 32/70
# 800/800 [==============================] - 331s 414ms/step - loss: 130.7944 - categorical_crossentropy: 1.0373 - categorical_accuracy: 0.7690 - top_3_accuracy: 0.9090 - val_loss: 133.1368 - val_categorical_crossentropy: 1.0440 - val_categorical_accuracy: 0.7659 - val_top_3_accuracy: 0.9058
# Epoch 33/70
# 799/800 [============================>.] - ETA: 0s - loss: 130.7541 - categorical_crossentropy: 1.0355 - categorical_accuracy: 0.7688 - top_3_accuracy: 0.9091
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0008437499636784196.
# 800/800 [==============================] - 329s 411ms/step - loss: 130.7326 - categorical_crossentropy: 1.0354 - categorical_accuracy: 0.7688 - top_3_accuracy: 0.9091 - val_loss: 133.2649 - val_categorical_crossentropy: 1.0484 - val_categorical_accuracy: 0.7640 - val_top_3_accuracy: 0.9064
# Epoch 34/70
# 800/800 [==============================] - 329s 412ms/step - loss: 128.1414 - categorical_crossentropy: 1.0219 - categorical_accuracy: 0.7736 - top_3_accuracy: 0.9106 - val_loss: 130.2562 - val_categorical_crossentropy: 1.0323 - val_categorical_accuracy: 0.7714 - val_top_3_accuracy: 0.9080
# Epoch 35/70
# 800/800 [==============================] - 330s 413ms/step - loss: 128.3082 - categorical_crossentropy: 1.0200 - categorical_accuracy: 0.7737 - top_3_accuracy: 0.9110 - val_loss: 129.2896 - val_categorical_crossentropy: 1.0299 - val_categorical_accuracy: 0.7718 - val_top_3_accuracy: 0.9096
# Epoch 36/70
# 800/800 [==============================] - 330s 412ms/step - loss: 127.2297 - categorical_crossentropy: 1.0152 - categorical_accuracy: 0.7755 - top_3_accuracy: 0.9109 - val_loss: 129.5182 - val_categorical_crossentropy: 1.0362 - val_categorical_accuracy: 0.7716 - val_top_3_accuracy: 0.9089
# Epoch 37/70
# 800/800 [==============================] - 332s 414ms/step - loss: 127.3971 - categorical_crossentropy: 1.0151 - categorical_accuracy: 0.7758 - top_3_accuracy: 0.9114 - val_loss: 129.7522 - val_categorical_crossentropy: 1.0281 - val_categorical_accuracy: 0.7722 - val_top_3_accuracy: 0.9086
# Epoch 38/70
# 799/800 [============================>.] - ETA: 0s - loss: 125.9895 - categorical_crossentropy: 1.0058 - categorical_accuracy: 0.7767 - top_3_accuracy: 0.9130
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0006328124727588147.
# 800/800 [==============================] - 329s 412ms/step - loss: 125.9838 - categorical_crossentropy: 1.0058 - categorical_accuracy: 0.7767 - top_3_accuracy: 0.9130 - val_loss: 127.3977 - val_categorical_crossentropy: 1.0165 - val_categorical_accuracy: 0.7751 - val_top_3_accuracy: 0.9104
# Epoch 39/70
# 800/800 [==============================] - 329s 411ms/step - loss: 125.2717 - categorical_crossentropy: 1.0034 - categorical_accuracy: 0.7786 - top_3_accuracy: 0.9125 - val_loss: 127.4291 - val_categorical_crossentropy: 1.0184 - val_categorical_accuracy: 0.7778 - val_top_3_accuracy: 0.9102
# Epoch 40/70
# 800/800 [==============================] - 329s 412ms/step - loss: 124.9671 - categorical_crossentropy: 1.0000 - categorical_accuracy: 0.7800 - top_3_accuracy: 0.9136 - val_loss: 126.0035 - val_categorical_crossentropy: 1.0123 - val_categorical_accuracy: 0.7783 - val_top_3_accuracy: 0.9110
# Epoch 41/70
# 800/800 [==============================] - 332s 415ms/step - loss: 124.2722 - categorical_crossentropy: 0.9962 - categorical_accuracy: 0.7808 - top_3_accuracy: 0.9138 - val_loss: 125.9420 - val_categorical_crossentropy: 1.0054 - val_categorical_accuracy: 0.7794 - val_top_3_accuracy: 0.9115
# Epoch 42/70
# 800/800 [==============================] - 331s 414ms/step - loss: 123.9552 - categorical_crossentropy: 0.9945 - categorical_accuracy: 0.7805 - top_3_accuracy: 0.9143 - val_loss: 125.2927 - val_categorical_crossentropy: 1.0013 - val_categorical_accuracy: 0.7791 - val_top_3_accuracy: 0.9123
# Epoch 43/70
# 800/800 [==============================] - 329s 412ms/step - loss: 124.1635 - categorical_crossentropy: 0.9951 - categorical_accuracy: 0.7811 - top_3_accuracy: 0.9144 - val_loss: 126.8039 - val_categorical_crossentropy: 1.0189 - val_categorical_accuracy: 0.7760 - val_top_3_accuracy: 0.9123
# Epoch 44/70
# 800/800 [==============================] - 330s 412ms/step - loss: 123.4716 - categorical_crossentropy: 0.9911 - categorical_accuracy: 0.7815 - top_3_accuracy: 0.9149 - val_loss: 125.7199 - val_categorical_crossentropy: 0.9973 - val_categorical_accuracy: 0.7800 - val_top_3_accuracy: 0.9121
# Epoch 45/70
# 799/800 [============================>.] - ETA: 0s - loss: 123.6585 - categorical_crossentropy: 0.9911 - categorical_accuracy: 0.7813 - top_3_accuracy: 0.9142
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.00047460937639698386.
# 800/800 [==============================] - 330s 412ms/step - loss: 123.6752 - categorical_crossentropy: 0.9912 - categorical_accuracy: 0.7813 - top_3_accuracy: 0.9142 - val_loss: 124.5482 - val_categorical_crossentropy: 0.9980 - val_categorical_accuracy: 0.7810 - val_top_3_accuracy: 0.9129
# Epoch 46/70
# 800/800 [==============================] - 332s 415ms/step - loss: 122.5582 - categorical_crossentropy: 0.9848 - categorical_accuracy: 0.7833 - top_3_accuracy: 0.9155 - val_loss: 123.6678 - val_categorical_crossentropy: 0.9909 - val_categorical_accuracy: 0.7832 - val_top_3_accuracy: 0.9142
# Epoch 47/70
# 800/800 [==============================] - 329s 411ms/step - loss: 121.3888 - categorical_crossentropy: 0.9785 - categorical_accuracy: 0.7849 - top_3_accuracy: 0.9166 - val_loss: 123.1312 - val_categorical_crossentropy: 0.9882 - val_categorical_accuracy: 0.7841 - val_top_3_accuracy: 0.9135
# Epoch 48/70
# 800/800 [==============================] - 328s 410ms/step - loss: 121.6115 - categorical_crossentropy: 0.9791 - categorical_accuracy: 0.7849 - top_3_accuracy: 0.9162 - val_loss: 122.2334 - val_categorical_crossentropy: 0.9833 - val_categorical_accuracy: 0.7850 - val_top_3_accuracy: 0.9136
# Epoch 49/70
# 799/800 [============================>.] - ETA: 0s - loss: 121.7477 - categorical_crossentropy: 0.9805 - categorical_accuracy: 0.7844 - top_3_accuracy: 0.9160
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.0003559570322977379.
# 800/800 [==============================] - 331s 413ms/step - loss: 121.7502 - categorical_crossentropy: 0.9805 - categorical_accuracy: 0.7844 - top_3_accuracy: 0.9160 - val_loss: 122.4012 - val_categorical_crossentropy: 0.9803 - val_categorical_accuracy: 0.7860 - val_top_3_accuracy: 0.9149
# Epoch 50/70
# 800/800 [==============================] - 330s 413ms/step - loss: 119.8080 - categorical_crossentropy: 0.9677 - categorical_accuracy: 0.7873 - top_3_accuracy: 0.9178 - val_loss: 121.6445 - val_categorical_crossentropy: 0.9780 - val_categorical_accuracy: 0.7873 - val_top_3_accuracy: 0.9152
# Epoch 51/70
# 800/800 [==============================] - 332s 415ms/step - loss: 120.2186 - categorical_crossentropy: 0.9708 - categorical_accuracy: 0.7880 - top_3_accuracy: 0.9171 - val_loss: 121.3312 - val_categorical_crossentropy: 0.9721 - val_categorical_accuracy: 0.7875 - val_top_3_accuracy: 0.9145
# Epoch 52/70
# 800/800 [==============================] - 329s 412ms/step - loss: 120.2291 - categorical_crossentropy: 0.9701 - categorical_accuracy: 0.7866 - top_3_accuracy: 0.9173 - val_loss: 121.2718 - val_categorical_crossentropy: 0.9776 - val_categorical_accuracy: 0.7871 - val_top_3_accuracy: 0.9153
# Epoch 53/70
# 799/800 [============================>.] - ETA: 0s - loss: 120.4191 - categorical_crossentropy: 0.9717 - categorical_accuracy: 0.7867 - top_3_accuracy: 0.9173
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.000266967763309367.
# 800/800 [==============================] - 329s 412ms/step - loss: 120.4089 - categorical_crossentropy: 0.9717 - categorical_accuracy: 0.7867 - top_3_accuracy: 0.9172 - val_loss: 121.2120 - val_categorical_crossentropy: 0.9710 - val_categorical_accuracy: 0.7874 - val_top_3_accuracy: 0.9147
# Epoch 54/70
# 800/800 [==============================] - 329s 411ms/step - loss: 119.4887 - categorical_crossentropy: 0.9669 - categorical_accuracy: 0.7890 - top_3_accuracy: 0.9179 - val_loss: 120.5091 - val_categorical_crossentropy: 0.9680 - val_categorical_accuracy: 0.7893 - val_top_3_accuracy: 0.9160
# Epoch 55/70
# 800/800 [==============================] - 329s 412ms/step - loss: 119.0684 - categorical_crossentropy: 0.9628 - categorical_accuracy: 0.7893 - top_3_accuracy: 0.9187 - val_loss: 119.8611 - val_categorical_crossentropy: 0.9659 - val_categorical_accuracy: 0.7901 - val_top_3_accuracy: 0.9158
# Epoch 56/70
# 799/800 [============================>.] - ETA: 0s - loss: 119.6031 - categorical_crossentropy: 0.9671 - categorical_accuracy: 0.7883 - top_3_accuracy: 0.9180
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.00020022581156808883.
# 800/800 [==============================] - 330s 413ms/step - loss: 119.6063 - categorical_crossentropy: 0.9672 - categorical_accuracy: 0.7883 - top_3_accuracy: 0.9179 - val_loss: 119.8826 - val_categorical_crossentropy: 0.9669 - val_categorical_accuracy: 0.7892 - val_top_3_accuracy: 0.9157
# Epoch 57/70
# 800/800 [==============================] - 330s 413ms/step - loss: 118.1560 - categorical_crossentropy: 0.9581 - categorical_accuracy: 0.7900 - top_3_accuracy: 0.9193 - val_loss: 119.4398 - val_categorical_crossentropy: 0.9614 - val_categorical_accuracy: 0.7904 - val_top_3_accuracy: 0.9166
# Epoch 58/70
# 800/800 [==============================] - 329s 411ms/step - loss: 118.3330 - categorical_crossentropy: 0.9586 - categorical_accuracy: 0.7901 - top_3_accuracy: 0.9192 - val_loss: 119.2494 - val_categorical_crossentropy: 0.9610 - val_categorical_accuracy: 0.7906 - val_top_3_accuracy: 0.9164
# Epoch 59/70
# 800/800 [==============================] - 330s 412ms/step - loss: 118.3021 - categorical_crossentropy: 0.9585 - categorical_accuracy: 0.7907 - top_3_accuracy: 0.9191 - val_loss: 119.2139 - val_categorical_crossentropy: 0.9646 - val_categorical_accuracy: 0.7895 - val_top_3_accuracy: 0.9166
# Epoch 60/70
# 799/800 [============================>.] - ETA: 0s - loss: 118.6461 - categorical_crossentropy: 0.9608 - categorical_accuracy: 0.7909 - top_3_accuracy: 0.9188
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 0.00015016935867606662.
# 800/800 [==============================] - 328s 410ms/step - loss: 118.6468 - categorical_crossentropy: 0.9608 - categorical_accuracy: 0.7909 - top_3_accuracy: 0.9188 - val_loss: 119.0184 - val_categorical_crossentropy: 0.9575 - val_categorical_accuracy: 0.7916 - val_top_3_accuracy: 0.9166
# Epoch 61/70
# 800/800 [==============================] - 329s 412ms/step - loss: 118.0737 - categorical_crossentropy: 0.9567 - categorical_accuracy: 0.7913 - top_3_accuracy: 0.9194 - val_loss: 118.6476 - val_categorical_crossentropy: 0.9581 - val_categorical_accuracy: 0.7926 - val_top_3_accuracy: 0.9173
# Epoch 62/70
# 800/800 [==============================] - 330s 412ms/step - loss: 117.2572 - categorical_crossentropy: 0.9524 - categorical_accuracy: 0.7922 - top_3_accuracy: 0.9199 - val_loss: 118.3984 - val_categorical_crossentropy: 0.9536 - val_categorical_accuracy: 0.7926 - val_top_3_accuracy: 0.9174
# Epoch 63/70
# 799/800 [============================>.] - ETA: 0s - loss: 112.6865 - categorical_crossentropy: 0.9243 - categorical_accuracy: 0.7989 - top_3_accuracy: 0.9232
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 0.00011262702173553407.
# 800/800 [==============================] - 326s 407ms/step - loss: 112.6898 - categorical_crossentropy: 0.9243 - categorical_accuracy: 0.7989 - top_3_accuracy: 0.9232 - val_loss: 118.4576 - val_categorical_crossentropy: 0.9470 - val_categorical_accuracy: 0.7923 - val_top_3_accuracy: 0.9170
# Epoch 64/70
# 800/800 [==============================] - 326s 408ms/step - loss: 115.7084 - categorical_crossentropy: 0.9411 - categorical_accuracy: 0.7945 - top_3_accuracy: 0.9209 - val_loss: 118.2222 - val_categorical_crossentropy: 0.9483 - val_categorical_accuracy: 0.7925 - val_top_3_accuracy: 0.9171
# Epoch 65/70
# 800/800 [==============================] - 326s 408ms/step - loss: 113.0537 - categorical_crossentropy: 0.9250 - categorical_accuracy: 0.7990 - top_3_accuracy: 0.9229 - val_loss: 117.9424 - val_categorical_crossentropy: 0.9449 - val_categorical_accuracy: 0.7936 - val_top_3_accuracy: 0.9174
# Epoch 66/70
# 800/800 [==============================] - 326s 407ms/step - loss: 114.3158 - categorical_crossentropy: 0.9319 - categorical_accuracy: 0.7966 - top_3_accuracy: 0.9223 - val_loss: 118.0222 - val_categorical_crossentropy: 0.9497 - val_categorical_accuracy: 0.7948 - val_top_3_accuracy: 0.9181
# Epoch 67/70
# 800/800 [==============================] - 326s 407ms/step - loss: 114.2000 - categorical_crossentropy: 0.9340 - categorical_accuracy: 0.7973 - top_3_accuracy: 0.9223 - val_loss: 117.9019 - val_categorical_crossentropy: 0.9465 - val_categorical_accuracy: 0.7933 - val_top_3_accuracy: 0.9185
# Epoch 68/70
# 800/800 [==============================] - 326s 408ms/step - loss: 113.9695 - categorical_crossentropy: 0.9295 - categorical_accuracy: 0.7972 - top_3_accuracy: 0.9223 - val_loss: 117.9649 - val_categorical_crossentropy: 0.9503 - val_categorical_accuracy: 0.7946 - val_top_3_accuracy: 0.9179
# Epoch 69/70
# 799/800 [============================>.] - ETA: 0s - loss: 113.6267 - categorical_crossentropy: 0.9296 - categorical_accuracy: 0.7973 - top_3_accuracy: 0.9229
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 8.447026630165055e-05.
# 800/800 [==============================] - 326s 408ms/step - loss: 113.6224 - categorical_crossentropy: 0.9295 - categorical_accuracy: 0.7973 - top_3_accuracy: 0.9229 - val_loss: 118.0068 - val_categorical_crossentropy: 0.9466 - val_categorical_accuracy: 0.7936 - val_top_3_accuracy: 0.9180
# Epoch 70/70
# 800/800 [==============================] - 326s 408ms/step - loss: 114.6513 - categorical_crossentropy: 0.9335 - categorical_accuracy: 0.7971 - top_3_accuracy: 0.9222 - val_loss: 117.6519 - val_categorical_crossentropy: 0.9488 - val_categorical_accuracy: 0.7940 - val_top_3_accuracy: 0.9185

# %%
hist_df = pd.concat([pd.DataFrame(hist.history) for hist in hists], sort=True)
hist_df.index = np.arange(1, len(hist_df)+1)
fig, axs = plt.subplots(nrows=2, sharex=True, figsize=(16, 10))
axs[0].plot(hist_df.val_categorical_accuracy, lw=5, label='Validation Accuracy')
axs[0].plot(hist_df.categorical_accuracy, lw=5, label='Training Accuracy')
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].grid()
axs[0].legend(loc=0)
axs[1].plot(hist_df.val_categorical_crossentropy, lw=5, label='Validation MLogLoss')
axs[1].plot(hist_df.categorical_crossentropy, lw=5, label='Training MLogLoss')
axs[1].set_ylabel('MLogLoss')
axs[1].set_xlabel('Epoch')
axs[1].grid()
axs[1].legend(loc=0)
fig.savefig('MobileV1FL.png', dpi=300)
plt.show();

# %%
hist_df.to_csv("history_of_MobileV1FL.csv")

# %%
valid_predictions = model.predict(x_valid, batch_size=128, verbose=1)
map3 = mapk(valid_df[['y']].values, preds2catids(valid_predictions).values)
print('Map3: {:.3f}'.format(map3))
# Out:
# 34000/34000 [==============================] - 7s 212us/step
# Map3: 0.849

# %%
model.load_weights("MobileV1FL.h5")

# %%
model.save_weights("MobileV1FL_weights.h5")

# %%
test = pd.read_csv(os.path.join(INPUT_DIR, 'test_simplified.csv'))
test.head()
x_test = df_to_image_array_xd(test, size)
print(test.shape, x_test.shape)
print('Test array memory {:.2f} GB'.format(x_test.nbytes / 1024.**3 ))
# Out:
#              key_id countrycode  \
# 0  9000003627287624          DE
# 1  9000010688666847          UA
# 2  9000023642890129          BG
# 3  9000038588854897          US
# 4  9000052667981386          AR
#
#                                              drawing
# 0  [[[17, 18, 20, 25, 137, 174, 242, 249, 251, 25...
# 1  [[[174, 145, 106, 38, 11, 4, 4, 15, 29, 78, 16...
# 2  [[[0, 12, 14, 17, 16, 24, 55, 57, 60, 79, 82, ...
# 3  [[[0, 9, 23, 40, 54, 60, 81, 105, 123, 167, 20...
# 4  [[[87, 82, 71, 63, 66, 92, 96, 95], [220, 218,...

# %%
test_predictions = model.predict(x_test, batch_size=128, verbose=1)

top3 = preds2catids(test_predictions)
top3.head()
top3.shape

cats = list_all_categories()
id2cat = {k: cat.replace(' ', '_') for k, cat in enumerate(cats)}
top3cats = top3.replace(id2cat)
top3cats.head()
top3cats.shape

# %%
test['word'] = top3cats['a'] + ' ' + top3cats['b'] + ' ' + top3cats['c']
submission = test[['key_id', 'word']]
submission.to_csv('submission_{}MobileV1FLmax.csv'.format(int(map3 * 10**4)), index=False)
submission.head()
submission.shape

# %%
end = dt.datetime.now()
print('Latest run {}.\nTotal time {}s'.format(end, (end - start).seconds))
# Out:
# Latest run 2019-01-09 06:10:29.909227.
# Total time 23188s
